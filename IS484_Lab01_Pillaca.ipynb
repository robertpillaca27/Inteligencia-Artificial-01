# %%
import numpy as np
import pandas as pd
import matplotlib
import sklearn
import scipy
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Scikit-learn:", sklearn.__version__)
print("SciPy:", scipy.__version__)
# Out:
# NumPy: 2.0.2
# Pandas: 2.3.3
# Matplotlib: 3.9.4
# Scikit-learn: 1.6.1
# SciPy: 1.13.1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
np.random.seed(42)
n = 300
hora = np.random.randint(0, 24, n)
monto = np.random.exponential(scale=150, size=n) + 10
# Fraude mas probable de madrugada (0-5h, 23h) y en montos altos
prob_fraude = 0.03 + 0.35 * ((hora <= 5) | (hora >= 23)) + 0.25 * (monto > 400)
prob_fraude = np.clip(prob_fraude, 0, 0.9)
es_fraude = (np.random.rand(n) < prob_fraude).astype(int)
transacciones = pd.DataFrame({"hora": hora, "monto": monto, "es_fraude": es_fraude})
colores = {0: "#0ca30c", 1: "#d03b3b"} # verde = legitima, rojo = fraude
etiquetas = {0: "Legitima", 1: "Fraude"}
fig, ax = plt.subplots(figsize=(10, 6), facecolor="#fcfcfb")
ax.set_facecolor("#fcfcfb")
for valor in [0, 1]:
    subset = transacciones[transacciones["es_fraude"] == valor]
    ax.scatter(
        subset["hora"], subset["monto"],
        s=70, alpha=0.75,
        c=colores[valor],
        edgecolors="white", linewidths=0.6,
        label=etiquetas[valor],
)
ax.set_title("Transacciones por hora y monto", fontsize=15, color="#0b0b0b", pad=14)
ax.set_xlabel("Hora del dia", fontsize=11, color="#52514e")
ax.set_ylabel("Monto (S/)", fontsize=11, color="#52514e")
ax.set_xticks(range(0, 24, 2))
ax.grid(True, color="#e1e0d9", linewidth=0.8)
ax.spines[["top", "right"]].set_visible(False)
ax.legend(title="Tipo de transaccion", frameon=False, loc="upper right")
plt.tight_layout()
plt.show()
print("Total transacciones:", len(transacciones),
"| Fraudes:", transacciones["es_fraude"].sum())
# Out:
# Total transacciones: 300 | Fraudes: 50

# %%
##5.4. Implementación

# %%
def agente_termostato(temperatura_actual, temperatura_objetivo=22, margen=1.0):
  
    diferencia = temperatura_actual - temperatura_objetivo
    if diferencia > margen:
        return "encender ventilador"
    elif diferencia < -margen:
        return "encender calefacción"
    else:
        return "No hacer ninguna acción"

# %%
print(agente_termostato(25))
print(agente_termostato(20))
print(agente_termostato(22.5))
print(agente_termostato(21))
# Out:
# encender ventilador
# encender calefacción
# No hacer ninguna acción
# No hacer ninguna acción

# %%
##5.5. Simulación

# %%
percepciones = [18.0, 19.5, 21.8, 24.3, 26.0, 23.0, 20.5, 21.0, 23.01]

print("RESULTADOS DE LA SIMULACIÓN:")
for t in percepciones:
    accion = agente_termostato(t)
    print(f"Percepción: {t}°C -> Acción del agente: {accion}")
# Out:
# RESULTADOS DE LA SIMULACIÓN:
# Percepción: 18.0°C -> Acción del agente: encender calefacción
# Percepción: 19.5°C -> Acción del agente: encender calefacción
# Percepción: 21.8°C -> Acción del agente: No hacer ninguna acción
# Percepción: 24.3°C -> Acción del agente: encender ventilador
# Percepción: 26.0°C -> Acción del agente: encender ventilador
# Percepción: 23.0°C -> Acción del agente: No hacer ninguna acción
# Percepción: 20.5°C -> Acción del agente: encender calefacción
# Percepción: 21.0°C -> Acción del agente: No hacer ninguna acción
# Percepción: 23.01°C -> Acción del agente: encender ventilador

# %%
##5.9. Extensión para la casa (Parte C)

# %%
def agente_riego(humedad_suelo, llovera_hoy):
    # Reglas de decisión combinadas
    if humedad_suelo < 30 and not llovera_hoy:
        return "Regar"
    elif humedad_suelo < 30 and llovera_hoy:
        return "No regar"
    else:
        return "No regar"

# %%
casos_humedad = [15, 25, 50, 80, 29] # Solo definimos las humedades

casos = []
for humedad in casos_humedad:
    lluvia_simulada = False if humedad < 30 else True
    casos.append((humedad, lluvia_simulada))

print("PRUEBAS DEL AGENTE DE RIEGO CON LLUVIA CONDICIONAL: ")
for humedad, lluvia in casos:
    res = agente_riego(humedad, lluvia)
    print(f"Humedad: {humedad}%, Lluvia: {lluvia} -> Acción: {res}")
# Out:
# PRUEBAS DEL AGENTE DE RIEGO CON LLUVIA CONDICIONAL:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 10
#       8 print("PRUEBAS DEL AGENTE DE RIEGO CON LLUVIA CONDICIONAL: ")
#       9 for humedad, lluvia in casos:
# ---> 10     res = agente_riego(humedad, lluvia)
#      11     print(f"Humedad: {humedad}%, Lluvia: {lluvia} -> Acción: {res}")
#
# NameError: name 'agente_riego' is not defined

# %%
##5.9. Extensión para la casa (Parte D)

# %%
# Out:
# PRUEBAS DEL AGENTE DE RIEGO CON LLUVIA CONDICIONAL:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 10
#       8 print("PRUEBAS DEL AGENTE DE RIEGO CON LLUVIA CONDICIONAL: ")
#       9 for humedad, lluvia in casos:
# ---> 10     res = agente_riego(humedad, lluvia)
#      11     print(f"Humedad: {humedad}%, Lluvia: {lluvia} -> Acción: {res}")
#
# NameError: name 'agente_riego' is not defined
